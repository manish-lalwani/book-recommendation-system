# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/BooksDataset.csv")

# %%
df.head(10)
# Out:
#                                                Title  \
# 0                                      Goat Brothers
# 1                                 The Missing Person
# 2                  Don't Eat Your Heart Out Cookbook
# 3  When Your Corporate Umbrella Begins to Leak: A...
# 4    Amy Spangler's Breastfeeding : A Parent's Guide
# 5  The Foundation of Leadership: Enduring Princip...
# 6  Chicken Soup for the Soul: 101 Stories to Open...
# 7                         Journey Through Heartsongs
# 8                       In Search of Melancholy Baby
# 9                                  Christmas Cookies
#
#                                              Authors  \
# 0                                   By Colton, Larry
# 1                                 By Grumbach, Doris
# 2                           By Piscatella, Joseph C.
# 3                                  By Davis, Paul D.
# 4                                   By Spangler, Amy
# 5                                       By Short, Bo
# 6  By Canfield, Jack (COM) and Hansen, Mark Victo...
# 7                          By Stepanek, Mattie J. T.
# 8  By Aksyonov, Vassily, Heim, Michael Henry, and...
# 9     By Eakin, Katherine M. and Deaman, Joane (EDT)
#
#                                          Description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Collects poems written by the eleven-year-old ...
# 8  The Russian author offers an affectionate chro...
# 9                                                NaN
#
#                                      Category                  Publisher  \
# 0                           History , General                  Doubleday
# 1                           Fiction , General           Putnam Pub Group
# 2                         Cooking , Reference             Workman Pub Co
# 3                                         NaN              Natl Pr Books
# 4                                         NaN               Amy Spangler
# 5                                         NaN            Excalibur Press
# 6   Self-help , Personal Growth , Self-Esteem  Health Communications Inc
# 7                            Poetry , General                  VSP Books
# 8         Biography & Autobiography , General               Random House
# 9                           Cooking , General               Oxmoor House
#
#                   Publish Date                     Price
# 0      Friday, January 1, 1993   Price Starting at $8.79
# 1        Sunday, March 1, 1981   Price Starting at $4.99
# 2  Thursday, September 1, 1983   Price Starting at $4.99
# 3        Monday, April 1, 1991   Price Starting at $4.99
# 4   Saturday, February 1, 1997   Price Starting at $5.32
# 5   Wednesday, January 1, 1997   Price Starting at $6.06
# 6        Saturday, May 1, 1993   Price Starting at $4.99
# 7  Saturday, September 1, 2001  Price Starting at $19.96
# 8         Monday, June 1, 1987   Price Starting at $4.99
# 9         Sunday, June 1, 1986  Price Starting at $12.98

# %%
df.shape
# Out:
# (70213, 7)

# %%
# Remove books with null descriptions
df = df[df['Description'].notnull()]

# %%
df["Description"] = df["Description"].fillna('')

# %%
df.head(10)
# Out:
#                                                 Title  \
# 7                          Journey Through Heartsongs
# 8                        In Search of Melancholy Baby
# 10       The Dieter's Guide to Weight Loss During Sex
# 11  Germs : Biological Weapons and America's Secre...
# 13  The Good Book: Reading the Bible with Mind and...
# 14                          All over but the Shoutin'
# 19             Hill Rat: Blowing the Lid Off Congress
# 21                             Personality of the Cat
# 26  Betrayal : How the Clinton Administration Unde...
# 27                                        Shadow Song
#
#                                               Authors  \
# 7                           By Stepanek, Mattie J. T.
# 8   By Aksyonov, Vassily, Heim, Michael Henry, and...
# 10                                  By Smith, Richard
# 11  By Miller, Judith, Engelberg, Stephen, and Bro...
# 13                                 By Gomes, Peter J.
# 14                                     By Bragg, Rick
# 19                                By Jackley, John L.
# 21                             By Aymar, Brandt (EDT)
# 26                                     By Gertz, Bill
# 27                                      By Kay, Terry
#
#                                           Description  \
# 7   Collects poems written by the eleven-year-old ...
# 8   The Russian author offers an affectionate chro...
# 10  A humor classic, this tongue-in-cheek diet pla...
# 11  Deadly germs sprayed in shopping malls, bomb-l...
# 13  "The Bible and the social and moral consequenc...
# 14  A New York Times Notable Book of the YearThis ...
# 19  As a top aide to powerful Texas Congressman Ro...
# 21  A delightful collection of reflections on the ...
# 26  Gertz, writer for the Moonie-influenced  Washi...
# 27  It was a wonderful summer, a great memory, the...
#
#                                          Category                   Publisher  \
# 7                                Poetry , General                   VSP Books
# 8             Biography & Autobiography , General                Random House
# 10    Health & Fitness , Diet & Nutrition , Diets  Workman Publishing Company
# 11    Technology & Engineering , Military Science            Simon & Schuster
# 13        Religion , Biblical Biography , General            Harper Perennial
# 14   Biography & Autobiography , Personal Memoirs                     Vintage
# 19                    Political Science , General    Regnery Publishing, Inc.
# 21                          Pets , Cats , General               Bonanza Books
# 26                    Political Science , General                 Regnery Pub
# 27                              Fiction , General                 Atria Books
#
#                    Publish Date                     Price
# 7   Saturday, September 1, 2001  Price Starting at $19.96
# 8          Monday, June 1, 1987   Price Starting at $4.99
# 10      Sunday, January 1, 1978   Price Starting at $4.99
# 11      Monday, October 1, 2001   Price Starting at $4.99
# 13          Friday, May 1, 1998   Price Starting at $5.29
# 14   Tuesday, September 1, 1998   Price Starting at $4.89
# 19     Wednesday, April 1, 1992   Price Starting at $4.99
# 21      Sunday, January 1, 1978   Price Starting at $5.41
# 26        Saturday, May 1, 1999   Price Starting at $4.99
# 27    Saturday, October 1, 1994   Price Starting at $4.99

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)

# %%
vectorizer
# Out:
# TfidfVectorizer(max_features=5000, stop_words='english')

# %%
description_vectors = vectorizer.fit_transform(df["Description"])

# %%
description_vectors.shape
# Out:
# (70213, 5000)

# %%
description_vectors
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2940105 stored elements and shape (70213, 5000)>

# %%
dense_matrix = description_vectors.todense()

# %%
dense_matrix[0]
# Out:
# matrix([[0., 0., 0., ..., 0., 0., 0.]])

# %%
description_vectors[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 15 stored elements and shape (1, 5000)>

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nn = NearestNeighbors(metric='cosine', algorithm='brute')

# %%
nn.fit(description_vectors)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def get_description_from_title(title,df):
    result =  df[df['Title'].str.lower() == title.lower()]
    if not result.empty:
        return result.iloc[0]["Description"]
    else:
        return None

# %%
def get_recommendations_by_title(book_title,nn_model,df,n_neighbors=5):
    book_description = get_description_from_title(book_title, df)
    if not book_description:
        return f"Book titled '{book_title}' not found."

    input_vector = vectorizer.transform([book_description])
    distances, indices = nn_model.kneighbors(input_vector,n_neighbors=n_neighbors)

    recommended_books = df['Title'].iloc[indices.flatten()[1:]]

    return recommended_books

# %%
df.iloc[7]
# Out:
# Title                                      Personality of the Cat
# Authors                                    By Aymar, Brandt (EDT)
# Description     A delightful collection of reflections on the ...
# Category                                    Pets , Cats , General
# Publisher                                           Bonanza Books
# Publish Date                              Sunday, January 1, 1978
# Price                                     Price Starting at $5.41
# Name: 21, dtype: object

# %%
book_title = "110%: 110 Strategies For Feeling Great Every Day"  # Replace with the user's input

# %%
df["Title"]
# Out:
# 7                                Journey Through Heartsongs
# 8                              In Search of Melancholy Baby
# 10             The Dieter's Guide to Weight Loss During Sex
# 11        Germs : Biological Weapons and America's Secre...
# 13        The Good Book: Reading the Bible with Mind and...
#                                 ...
# 103069                               Like A Sister: A Novel
# 103071    Creating Web Pages Simplified (3-D Visual Series)
# 103072                 EVA: The Real Key to Creating Wealth
# 103075    The Essentials of Spanish (REA's Language Seri...
# 103081                 Your First Puppy (Your First Series)
# Name: Title, Length: 70213, dtype: object

# %%
recommendations = get_recommendations_by_title(book_title, nn, df)

# %%
recommendations
# Out:
# 21052    I Feel Great And You Will Too: An Inspiring Jo...
# 47078    Trevor's Place: The Story of the Boy Who Bring...
# 855      I Feel Great and You Will Too!: An Inspiring J...
# 52279    Making Peace With Your Past: The Six Essential...
# Name: Title, dtype: object
